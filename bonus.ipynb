# %%
# %matplotlib inline
import numpy as np
from scipy import ndimage
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # 讀取圖形

# %%
# 讀取影像
img = Image.open('lena.jpg')

# %%
img.size
# Out:
# (1960, 1960)

# %%
img.mode
# Out:
# 'RGB'

# %%
# 將彩色影像轉換成灰階影像
l_gray = img.convert('L')

# %%
l_gray.mode
# Out:
# 'L'

# %%
l_array = np.array(img_gray)

# %%
plt.imshow(l_array, cmap='gray');

# %%
l_array.shape
# Out:
# (1960, 1960)

# %% [markdown]
# # 防止 data overflow

# %%
l_array=l_array.astype('int64')

# %% [markdown]
# # sobel filter

# %%
sobelx = np.array([[1, 0, -1], [2, 0, -2], [1, 0, -1]], dtype = np.float )

# %%
sobely = np.array([[1, 2, 1], [0, 0, 0], [-1, -2, -1]], dtype = np.float)

# %%
# Convolve
outx = ndimage.convolve(l_array, sobelx).astype('float')

# %%
plt.imshow(outx, cmap='gray');

# %%
outy  =  ndimage.convolve(l_array, sobely).astype('float')

# %%
plt.imshow(outy, cmap='gray');

# %%
out = np.sqrt(outx*outx+outy*outy)

# %%
plt.imshow(out, cmap='gray');

# %% [markdown]
# # 試試其他圖

# %%
bike = Image.open('bike.jpg')

# %%
bike.size
# Out:
# (300, 225)

# %%
bike.mode
# Out:
# 'L'

# %%
b_array = np.array(bike)

# %%
b_array=b_array.astype('int64')

# %%
plt.imshow(b_array, cmap='gray');

# %%
bx = ndimage.convolve(b_array, sobelx).astype('float')

# %%
plt.imshow(bx, cmap='gray');

# %%
by = ndimage.convolve(b_array, sobely).astype('float')

# %%
plt.imshow(by, cmap='gray');

# %%
b = np.sqrt(bx*bx+by*by)

# %%
plt.imshow(b, cmap='gray');
